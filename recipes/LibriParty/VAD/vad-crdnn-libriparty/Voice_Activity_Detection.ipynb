# %% [markdown]
# # **Voice Activity Detection**
#
# The goal of Voice Activity Detection (VAD) is to **detect** the **segments** containing **speech** within an audio recording.
#
# As shown in the following picture, the input of a VAD is an audio signal (or its corresponding features). The output could be a sequence that is "1" for the time frames containing speech and "0" for non-speech frames.

# %% [markdown]
# ![SpeechBrain-VAD.png](data:image/png;base64,...)

# %% [markdown]
# As an alternative, the VAD could provide in the output the **boundaries** where speech activity is detected. For instance:
#
#
#
# ```
# segment_001  0.00  2.57 NON_SPEECH
# segment_002  2.57  8.20 SPEECH
# segment_003  8.20  9.10 NON_SPEECH
# segment_004  9.10  10.93 SPEECH
# segment_005  10.93  12.00 NON_SPEECH
# segment_006  12.00  14.40 SPEECH
# segment_007  14.40  15.00 NON_SPEECH
# ```

# %% [markdown]
# ## Why is needed?
#
# A VAD plays a crucial role in many speech processing pipelines. It is used when we would like to apply the processing algorithms to the **speech parts** of the audio recording only.
#
# For instance, it is often employed as a **pre-processing step** for speech recognition, speech enhancement, speaker diarization, and many others systems.

# %% [markdown]
# ## Why is challenging?

# %% [markdown]
# Discriminating speech from non-speech signals is very natural for humans. However, for a machine, this is much tricker. A good VAD should precisely detect speech activity even in **noisy** and **reverberant** conditions. The number of possible noise sources is huge in **real-life** conditions (e.g., music, telephone rings, alarms, etc.), making the problem challenging for a machine.
#
# Moreover, a good VAD should be able to process both short and very **long recordings** (e.g., meetings) and, ideally, shouldn't be too computationally expensive.

# %% [markdown]
# ## Pipeline description
#
# Robust Voice Activity Detection has been a very active research field for decades. Today, deep learning plays a crucial role in this problem as well.
#
# In this tutorial, we employ a neural network that provides speech/non-speech predictions for each input frame. The frame-level posterior probabilities are then post-processed to retrieve the final speech boundaries, as shown in the following figure:

# %% [markdown]
# ![SpeechBrain-VAD_CRDNN.png](data:image/png;base64,...)

# %% [markdown]
# More precisely, we here compute the standard FBANK features and we plug them into a CRDNN model (which combines convolutional, recurrent, and fully connected layers). The output is processed with a **sigmoid** to perform a **binary classification**. The network is trained with **binary cross-entropy**. The predictions will be close to one for speech and close to zero for non-speech frames.
#
# At inference time, the binary predictions are post-processed. For instance, we apply a **threshold** on them to identify the candidate speech regions. After that, we can apply other types of post-processing, such as merging segments that are close or remove segments that are too short. We will describe this in detail in the inference section.
#
# Right now, let's briefly discuss how we can train such a model with SpeechBrain.

# %% [markdown]
# ## Training
# SpeechBrain has a recipe for training a VAD with the [LibriParty Dataset](https://drive.google.com/file/d/1--cAS5ePojMwNY5fewioXAv9YlYAWzIJ/view?usp=sharing). This is a dataset that we created for tasks such a VAD training. It contains several simulated acoustic scenes with speech and noisy sequences periodically active (alone or simultaneously).
#
# Beyond that, the training recipe creates **on-the-fly** several other **simulated acoustic scenes** using the Musan (that contains speech, noise, and music signals), CommonLanguage (that contains speech from 48 languages), and open-rir (that contains noise and impulse responses).
#
# The acoustic scene simulated on the fly explores different scenarios such as noise + speech, speech to noise transitions, noise to speech transitions, etc.
#
# Similarly to the other SpeechBrain recipes, one can train the model with the following commands:
#
#
#
# ```bash
# cd recipes/LibriParty/VAD
# python train.py hparams/train.yaml
# ```
#
# Please, follow the README file available within the recipe and make sure you have downloaded all the data before starting the training.
#
# Apart from the **massive use of speech augmentation/contamination**, the recipe has nothing special. Let's thus focus more on the inference part, which relies on some custom components.

# %% [markdown]
# ## Inference
#
# We can now focus on the inference part. The inference part is a bit more elaborated than usual because we designed it to work on very **long recordings** and to support several techniques for **post-processing** the network predictions.
#
# We will address all of the aforementioned aspects. But, let's first install speechbrain:

# %%
# %%capture
# !wget https://www.dropbox.com/s/lkngxlybrh4zamh/example_vad_music.wav

# Local installation
# !git clone https://github.com/speechbrain/speechbrain/
# %cd /content/speechbrain/
# !pip install -r requirements.txt
# !pip install -e .

# As an alterative, use the PyPI installation
# !pip install speechbrain

# %% [markdown]
# Let's read a speech signal:

# %%
import torch
import torchaudio 
import matplotlib.pyplot as plt

audio_file = "example_vad.wav"
signal, fs = torchaudio.load(audio_file)
signal = signal.squeeze()
time = torch.linspace(0, signal.shape[0]/fs, steps=signal.shape[0])

plt.plot(time, signal)
plt.show()

# %% [markdown]
# We can now use the VAD trained at the previous step in the following way:

# %%
from speechbrain.pretrained import VAD

VAD = VAD.from_hparams(source="speechbrain/vad-crdnn-libriparty", savedir="pretrained_models/vad-crdnn-libriparty")
boundaries = VAD.get_speech_segments(audio_file)
VAD.save_boundaries(boundaries)
# Out:
# The torchaudio backend is switched to 'soundfile'. Note that 'sox_io' is not supported on Windows.
# The torchaudio backend is switched to 'soundfile'. Note that 'sox_io' is not supported on Windows.
# Downloading:   0%|          | 0.00/2.30k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/453k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# segment_001  0.00  5.60 SPEECH
# segment_002  5.60  14.34 NON_SPEECH
# segment_003  14.34  17.32 SPEECH
# segment_004  17.32  18.15 NON_SPEECH
# segment_005  18.15  21.63 SPEECH
# segment_006  21.63  28.56 NON_SPEECH
# segment_007  28.56  36.90 SPEECH
# segment_008  36.90  38.07 NON_SPEECH
# segment_009  38.07  51.26 SPEECH
# segment_010  51.26  62.54 NON_SPEECH
# segment_011  62.54  74.42 SPEECH
# segment_012  74.42  80.99 NON_SPEECH
# segment_013  80.99  94.65 SPEECH
# segment_014  94.65  97.20 NON_SPEECH
# segment_015  97.20  103.13 SPEECH
# segment_016  103.13  121.99 NON_SPEECH
# segment_017  121.99  128.80 SPEECH
# segment_018  128.80  147.61 NON_SPEECH
# segment_019  147.61  164.60 SPEECH
# segment_020  164.60  167.47 NON_SPEECH
# segment_021  167.47  172.65 SPEECH
# segment_022  172.65  205.78 NON_SPEECH
# segment_023  205.78  230.54 SPEECH
# segment_024  230.54  237.61 NON_SPEECH
# segment_025  237.61  245.98 SPEECH
# segment_026  245.98  246.73 NON_SPEECH
# segment_027  246.73  257.26 SPEECH
# segment_028  257.26  289.51 NON_SPEECH
# segment_029  289.51  299.63 SPEECH

# %% [markdown]
# As you can see, the two speech parts are detected correctly. The music part is correctly classified as a non-speech segment, while the part where both music and speech are active is classified as speech.

# %% [markdown]
# ## Inference Pipeline (Details)
#
# The pipeline for detecting the speech segments is the following:
#
# 1. Compute **posteriors probabilities** at the frame level.
# 2. Apply a **threshold** on the posterior probability.
# 3. Derive candidate speech segments on top of that.
# 4. Apply **energy VAD** within each candidate segment (optional).
# 5. **Merge segments** that are too close.
# 6. **Remove segments** that are too short.
# 7. **Double-check speech** segments (optional).
#
# To make debugging easier and the interface more **modular** and **transparent**, we allow users to access the output of these intermediate steps.
#
# In some cases, these steps are not all needed. Users are free to customize the pipeline and its hyperparameters to improve the performance on their data.
#
#
# Let's start with the posterior computation.
#
# ### 1- Posterior Computation
# The neural model provides outputs that should be close to zero for non-speech frames and close 1 one from speech frames.
#
# The time resolution depends on the **feature extraction** part and on the adopted neural **model**. In this case, we have a prediction every 10 ms (which is pretty standard for speech processing).
#
# To compute the posterior probabilities, you can use the following command:

# %%
prob_chunks = VAD.get_speech_prob_file(audio_file)
plt.plot(prob_chunks.squeeze())

# %% [markdown]
# As expected, we have high values for speech regions and low values for the music one.
#
# The `get_speech_prob_file function` is designed to process **long audio recordings**. It computes posterior probabilities on large chunks (e.g., 30 sec), that are read sequentially to avoid storing long signals in memory.
# Each large chunk is, in turn, split into smaller ones (e.g., 10 seconds)
# that are processed in parallel.
#
# You can tune the `large_chunk_size` and `small_chunk_size` based on your memory constraints. If you have enough memory, you can use it to store a larger chunk of the signal (e.g., 5 minutes). This can be done by increasing `large_chunk_size` and will make the VAD (slightly) faster.

# %% [markdown]
# ### 2- Apply a Threshold
#
# Now, we can detect the candidate speech segments by applying a threshold.
#
# To do it, you can use the following function:

# %%
prob_th = VAD.apply_threshold(prob_chunks, activation_th=0.5, deactivation_th=0.25).float()
plt.plot(prob_th.squeeze())

# %% [markdown]
# Instead of applying a single threshold (e.g., 0.5),  we allow users to set two different thresholds, one to decide when to start a speech segment (`activation_th`) and one to detect when to stop it (`deactivation_th`).
#
# According to our experience, it makes sense to set `activation_th` higher than than `deactivation_th` (e.g, `aactivation_th=0.5`, `deactivation_th=0.25`).
#
# Users, however, can play with these hyperparameters to make the VAD more or less selective.

# %% [markdown]
# ### 3- Get the Boundaries
# Now, we can derive the boundaries of the speech segments from the thresholded posteriors:

# %%
boundaries = VAD.get_boundaries(prob_th)
VAD.save_boundaries(boundaries, audio_file=audio_file)
# Out:
# segment_001  0.00  5.60 SPEECH
# segment_002  5.60  14.34 NON_SPEECH
# segment_003  14.34  17.32 SPEECH
# segment_004  17.32  18.15 NON_SPEECH
# segment_005  18.15  21.63 SPEECH
# segment_006  21.63  28.56 NON_SPEECH
# segment_007  28.56  36.90 SPEECH
# segment_008  36.90  38.07 NON_SPEECH
# segment_009  38.07  51.26 SPEECH
# segment_010  51.26  62.54 NON_SPEECH
# segment_011  62.54  74.42 SPEECH
# segment_012  74.42  80.99 NON_SPEECH
# segment_013  80.99  94.65 SPEECH
# segment_014  94.65  97.20 NON_SPEECH
# segment_015  97.20  103.13 SPEECH
# segment_016  103.13  121.99 NON_SPEECH
# segment_017  121.99  128.80 SPEECH
# segment_018  128.80  147.61 NON_SPEECH
# segment_019  147.61  164.60 SPEECH
# segment_020  164.60  167.47 NON_SPEECH
# segment_021  167.47  172.65 SPEECH
# segment_022  172.65  205.78 NON_SPEECH
# segment_023  205.78  230.54 SPEECH
# segment_024  230.54  237.61 NON_SPEECH
# segment_025  237.61  245.98 SPEECH
# segment_026  245.98  246.73 NON_SPEECH
# segment_027  246.73  257.26 SPEECH
# segment_028  257.26  289.51 NON_SPEECH
# segment_029  289.51  299.63 SPEECH
# segment_030  299.63  299.65 NON_SPEECH

# %% [markdown]
# The `boundaries` tensors contain the beginning and end second of each speech segment.
# The method `save_boundaries` can be used to plot the boundaries in a human-readable format and/or to save them on a file (with the `save_path` argument).

# %% [markdown]
# ### 4- Energy-based VAD (optional)
#
# The trained neural VAD tends to detect large speech segments, where smaller speech segments that are close to each other are merged.
#
# If the users want more resolution, one possible approach is to apply an **energy-based VAD** within the detected speech segments. The energy-based VAD processes the speech segments with sliding windows that compute the energy within each chunk.  The energy profile is normalized such that we have  0.5 and +-0.5 of standard deviation. We then apply a threshold and split the speech original segment into smaller ones.
#
# This is done in the following way:

# %%
boundaries = VAD.energy_VAD(audio_file,boundaries, activation_th=0.8, deactivation_th=0.0)
VAD.save_boundaries(boundaries, audio_file=audio_file)
# Out:
# segment_001  0.00  1.29 NON_SPEECH
# segment_002  1.29  1.86 SPEECH
# segment_003  1.86  2.08 NON_SPEECH
# segment_004  2.08  3.68 SPEECH
# segment_005  3.68  3.74 NON_SPEECH
# segment_006  3.74  5.02 SPEECH
# segment_007  5.02  14.75 NON_SPEECH
# segment_008  14.75  15.36 SPEECH
# segment_009  15.36  15.61 NON_SPEECH
# segment_010  15.61  16.01 SPEECH
# segment_011  16.01  16.13 NON_SPEECH
# segment_012  16.13  16.48 SPEECH
# segment_013  16.48  16.52 NON_SPEECH
# segment_014  16.52  17.15 SPEECH
# segment_015  17.15  18.33 NON_SPEECH
# segment_016  18.33  18.57 SPEECH
# segment_017  18.57  18.68 NON_SPEECH
# segment_018  18.68  19.46 SPEECH
# segment_019  19.46  19.50 NON_SPEECH
# segment_020  19.50  19.67 SPEECH
# segment_021  19.67  19.82 NON_SPEECH
# segment_022  19.82  20.16 SPEECH
# segment_023  20.16  20.22 NON_SPEECH
# segment_024  20.22  20.31 SPEECH
# segment_025  20.31  20.38 NON_SPEECH
# segment_026  20.38  20.51 SPEECH
# segment_027  20.51  28.69 NON_SPEECH
# segment_028  28.69  30.36 SPEECH
# segment_029  30.36  30.40 NON_SPEECH
# segment_030  30.40  31.40 SPEECH
# segment_031  31.40  31.61 NON_SPEECH
# segment_032  31.61  32.77 SPEECH
# segment_033  32.77  33.06 NON_SPEECH
# segment_034  33.06  33.33 SPEECH
# segment_035  33.33  33.63 NON_SPEECH
# segment_036  33.63  34.73 SPEECH
# segment_037  34.73  34.78 NON_SPEECH
# segment_038  34.78  35.00 SPEECH
# segment_039  35.00  35.12 NON_SPEECH
# segment_040  35.12  36.04 SPEECH
# segment_041  36.04  38.52 NON_SPEECH
# segment_042  38.52  39.24 SPEECH
# segment_043  39.24  39.50 NON_SPEECH
# segment_044  39.50  40.01 SPEECH
# segment_045  40.01  40.09 NON_SPEECH
# segment_046  40.09  40.47 SPEECH
# segment_047  40.47  40.54 NON_SPEECH
# segment_048  40.54  41.18 SPEECH
# segment_049  41.18  41.27 NON_SPEECH
# segment_050  41.27  41.45 SPEECH
# segment_051  41.45  41.55 NON_SPEECH
# segment_052  41.55  41.97 SPEECH
# segment_053  41.97  42.48 NON_SPEECH
# segment_054  42.48  42.84 SPEECH
# segment_055  42.84  43.10 NON_SPEECH
# segment_056  43.10  43.23 SPEECH
# segment_057  43.23  43.32 NON_SPEECH
# segment_058  43.32  43.50 SPEECH
# segment_059  43.50  43.53 NON_SPEECH
# segment_060  43.53  44.24 SPEECH
# segment_061  44.24  44.37 NON_SPEECH
# segment_062  44.37  44.61 SPEECH
# segment_063  44.61  44.70 NON_SPEECH
# segment_064  44.70  44.82 SPEECH
# segment_065  44.82  45.01 NON_SPEECH
# segment_066  45.01  45.16 SPEECH
# segment_067  45.16  45.33 NON_SPEECH
# segment_068  45.33  45.55 SPEECH
# segment_069  45.55  45.61 NON_SPEECH
# segment_070  45.61  46.20 SPEECH
# segment_071  46.20  46.23 NON_SPEECH
# segment_072  46.23  46.46 SPEECH
# segment_073  46.46  46.79 NON_SPEECH
# segment_074  46.79  47.65 SPEECH
# segment_075  47.65  47.88 NON_SPEECH
# segment_076  47.88  48.73 SPEECH
# segment_077  48.73  48.80 NON_SPEECH
# segment_078  48.80  49.09 SPEECH
# segment_079  49.09  49.67 NON_SPEECH
# segment_080  49.67  50.28 SPEECH
# segment_081  50.28  50.33 NON_SPEECH
# segment_082  50.33  50.57 SPEECH
# segment_083  50.57  50.74 NON_SPEECH
# segment_084  50.74  51.15 SPEECH
# segment_085  51.15  62.83 NON_SPEECH
# segment_086  62.83  62.98 SPEECH
# segment_087  62.98  63.04 NON_SPEECH
# segment_088  63.04  63.24 SPEECH
# segment_089  63.24  63.36 NON_SPEECH
# segment_090  63.36  63.90 SPEECH
# segment_091  63.90  64.02 NON_SPEECH
# segment_092  64.02  64.18 SPEECH
# segment_093  64.18  65.69 NON_SPEECH
# segment_094  65.69  65.80 SPEECH
# segment_095  65.80  65.96 NON_SPEECH
# segment_096  65.96  66.17 SPEECH
# segment_097  66.17  66.70 NON_SPEECH
# segment_098  66.70  66.84 SPEECH
# segment_099  66.84  67.20 NON_SPEECH
# segment_100  67.20  68.33 SPEECH
# segment_101  68.33  68.54 NON_SPEECH
# segment_102  68.54  69.99 SPEECH
# segment_103  69.99  70.28 NON_SPEECH
# segment_104  70.28  71.23 SPEECH
# segment_105  71.23  71.35 NON_SPEECH
# segment_106  71.35  71.81 SPEECH
# segment_107  71.81  71.85 NON_SPEECH
# segment_108  71.85  72.45 SPEECH
# segment_109  72.45  72.52 NON_SPEECH
# segment_110  72.52  72.73 SPEECH
# segment_111  72.73  72.85 NON_SPEECH
# segment_112  72.85  73.05 SPEECH
# segment_113  73.05  73.21 NON_SPEECH
# segment_114  73.21  74.24 SPEECH
# segment_115  74.24  81.41 NON_SPEECH
# segment_116  81.41  81.70 SPEECH
# segment_117  81.70  81.82 NON_SPEECH
# segment_118  81.82  82.49 SPEECH
# segment_119  82.49  82.97 NON_SPEECH
# segment_120  82.97  84.11 SPEECH
# segment_121  84.11  85.03 NON_SPEECH
# segment_122  85.03  85.19 SPEECH
# segment_123  85.19  85.26 NON_SPEECH
# segment_124  85.26  85.49 SPEECH
# segment_125  85.49  86.09 NON_SPEECH
# segment_126  86.09  86.25 SPEECH
# segment_127  86.25  86.68 NON_SPEECH
# segment_128  86.68  88.87 SPEECH
# segment_129  88.87  89.01 NON_SPEECH
# segment_130  89.01  92.14 SPEECH
# segment_131  92.14  92.78 NON_SPEECH
# segment_132  92.78  93.01 SPEECH
# segment_133  93.01  93.25 NON_SPEECH
# segment_134  93.25  94.38 SPEECH
# segment_135  94.38  97.54 NON_SPEECH
# segment_136  97.54  98.10 SPEECH
# segment_137  98.10  98.49 NON_SPEECH
# segment_138  98.49  102.39 SPEECH
# segment_139  102.39  102.46 NON_SPEECH
# segment_140  102.46  102.67 SPEECH
# segment_141  102.67  122.50 NON_SPEECH
# segment_142  122.50  122.65 SPEECH
# segment_143  122.65  122.82 NON_SPEECH
# segment_144  122.82  123.79 SPEECH
# segment_145  123.79  124.18 NON_SPEECH
# segment_146  124.18  127.30 SPEECH
# segment_147  127.30  127.46 NON_SPEECH
# segment_148  127.46  128.11 SPEECH
# segment_149  128.11  148.34 NON_SPEECH
# segment_150  148.34  148.84 SPEECH
# segment_151  148.84  149.07 NON_SPEECH
# segment_152  149.07  150.09 SPEECH
# segment_153  150.09  150.20 NON_SPEECH
# segment_154  150.20  151.14 SPEECH
# segment_155  151.14  151.21 NON_SPEECH
# segment_156  151.21  151.45 SPEECH
# segment_157  151.45  151.57 NON_SPEECH
# segment_158  151.57  151.80 SPEECH
# segment_159  151.80  152.05 NON_SPEECH
# segment_160  152.05  152.18 SPEECH
# segment_161  152.18  152.26 NON_SPEECH
# segment_162  152.26  152.54 SPEECH
# segment_163  152.54  152.64 NON_SPEECH
# segment_164  152.64  152.93 SPEECH
# segment_165  152.93  153.16 NON_SPEECH
# segment_166  153.16  153.38 SPEECH
# segment_167  153.38  153.48 NON_SPEECH
# segment_168  153.48  153.59 SPEECH
# segment_169  153.59  153.64 NON_SPEECH
# segment_170  153.64  153.91 SPEECH
# segment_171  153.91  153.99 NON_SPEECH
# segment_172  153.99  154.21 SPEECH
# segment_173  154.21  154.31 NON_SPEECH
# segment_174  154.31  154.85 SPEECH
# segment_175  154.85  154.96 NON_SPEECH
# segment_176  154.96  155.45 SPEECH
# segment_177  155.45  155.51 NON_SPEECH
# segment_178  155.51  156.23 SPEECH
# segment_179  156.23  156.51 NON_SPEECH
# segment_180  156.51  156.90 SPEECH
# segment_181  156.90  156.95 NON_SPEECH
# segment_182  156.95  157.28 SPEECH
# segment_183  157.28  157.35 NON_SPEECH
# segment_184  157.35  157.59 SPEECH
# segment_185  157.59  157.68 NON_SPEECH
# segment_186  157.68  157.89 SPEECH
# segment_187  157.89  157.96 NON_SPEECH
# segment_188  157.96  158.23 SPEECH
# segment_189  158.23  158.72 NON_SPEECH
# segment_190  158.72  158.88 SPEECH
# segment_191  158.88  159.03 NON_SPEECH
# segment_192  159.03  159.35 SPEECH
# segment_193  159.35  159.38 NON_SPEECH
# segment_194  159.38  159.98 SPEECH
# segment_195  159.98  160.03 NON_SPEECH
# segment_196  160.03  160.90 SPEECH
# segment_197  160.90  160.93 NON_SPEECH
# segment_198  160.93  161.50 SPEECH
# segment_199  161.50  161.58 NON_SPEECH
# segment_200  161.58  161.82 SPEECH
# segment_201  161.82  161.87 NON_SPEECH
# segment_202  161.87  162.09 SPEECH
# segment_203  162.09  162.19 NON_SPEECH
# segment_204  162.19  162.32 SPEECH
# segment_205  162.32  162.36 NON_SPEECH
# segment_206  162.36  163.00 SPEECH
# segment_207  163.00  163.10 NON_SPEECH
# segment_208  163.10  163.64 SPEECH
# segment_209  163.64  163.67 NON_SPEECH
# segment_210  163.67  163.78 SPEECH
# segment_211  163.78  163.95 NON_SPEECH
# segment_212  163.95  164.30 SPEECH
# segment_213  164.30  167.48 NON_SPEECH
# segment_214  167.48  167.58 SPEECH
# segment_215  167.58  167.67 NON_SPEECH
# segment_216  167.67  167.88 SPEECH
# segment_217  167.88  167.91 NON_SPEECH
# segment_218  167.91  168.37 SPEECH
# segment_219  168.37  168.44 NON_SPEECH
# segment_220  168.44  168.56 SPEECH
# segment_221  168.56  168.77 NON_SPEECH
# segment_222  168.77  169.17 SPEECH
# segment_223  169.17  169.38 NON_SPEECH
# segment_224  169.38  169.46 SPEECH
# segment_225  169.46  169.56 NON_SPEECH
# segment_226  169.56  169.60 SPEECH
# segment_227  169.60  169.72 NON_SPEECH
# segment_228  169.72  169.93 SPEECH
# segment_229  169.93  170.03 NON_SPEECH
# segment_230  170.03  170.28 SPEECH
# segment_231  170.28  170.36 NON_SPEECH
# segment_232  170.36  170.43 SPEECH
# segment_233  170.43  170.51 NON_SPEECH
# segment_234  170.51  170.65 SPEECH
# segment_235  170.65  170.86 NON_SPEECH
# segment_236  170.86  170.94 SPEECH
# segment_237  170.94  170.99 NON_SPEECH
# segment_238  170.99  171.50 SPEECH
# segment_239  171.50  171.63 NON_SPEECH
# segment_240  171.63  171.88 SPEECH
# segment_241  171.88  172.07 NON_SPEECH
# segment_242  172.07  172.31 SPEECH
# segment_243  172.31  206.12 NON_SPEECH
# segment_244  206.12  207.87 SPEECH
# segment_245  207.87  207.90 NON_SPEECH
# segment_246  207.90  209.11 SPEECH
# segment_247  209.11  209.17 NON_SPEECH
# segment_248  209.17  209.38 SPEECH
# segment_249  209.38  209.69 NON_SPEECH
# segment_250  209.69  210.60 SPEECH
# segment_251  210.60  210.72 NON_SPEECH
# segment_252  210.72  211.01 SPEECH
# segment_253  211.01  211.11 NON_SPEECH
# segment_254  211.11  211.64 SPEECH
# segment_255  211.64  211.75 NON_SPEECH
# segment_256  211.75  212.67 SPEECH
# segment_257  212.67  213.03 NON_SPEECH
# segment_258  213.03  213.74 SPEECH
# segment_259  213.74  213.85 NON_SPEECH
# segment_260  213.85  213.98 SPEECH
# segment_261  213.98  214.04 NON_SPEECH
# segment_262  214.04  214.79 SPEECH
# segment_263  214.79  215.86 NON_SPEECH
# segment_264  215.86  216.27 SPEECH
# segment_265  216.27  216.37 NON_SPEECH
# segment_266  216.37  216.80 SPEECH
# segment_267  216.80  217.22 NON_SPEECH
# segment_268  217.22  217.40 SPEECH
# segment_269  217.40  217.51 NON_SPEECH
# segment_270  217.51  217.66 SPEECH
# segment_271  217.66  217.71 NON_SPEECH
# segment_272  217.71  218.27 SPEECH
# segment_273  218.27  218.30 NON_SPEECH
# segment_274  218.30  218.51 SPEECH
# segment_275  218.51  218.60 NON_SPEECH
# segment_276  218.60  218.84 SPEECH
# segment_277  218.84  218.95 NON_SPEECH
# segment_278  218.95  220.64 SPEECH
# segment_279  220.64  220.71 NON_SPEECH
# segment_280  220.71  221.65 SPEECH
# segment_281  221.65  221.73 NON_SPEECH
# segment_282  221.73  221.88 SPEECH
# segment_283  221.88  222.00 NON_SPEECH
# segment_284  222.00  222.33 SPEECH
# segment_285  222.33  222.70 NON_SPEECH
# segment_286  222.70  223.52 SPEECH
# segment_287  223.52  223.57 NON_SPEECH
# segment_288  223.57  223.73 SPEECH
# segment_289  223.73  223.84 NON_SPEECH
# segment_290  223.84  224.06 SPEECH
# segment_291  224.06  224.12 NON_SPEECH
# segment_292  224.12  224.78 SPEECH
# segment_293  224.78  225.23 NON_SPEECH
# segment_294  225.23  225.40 SPEECH
# segment_295  225.40  225.62 NON_SPEECH
# segment_296  225.62  225.84 SPEECH
# segment_297  225.84  227.51 NON_SPEECH
# segment_298  227.51  227.71 SPEECH
# segment_299  227.71  227.79 NON_SPEECH
# segment_300  227.79  228.13 SPEECH
# segment_301  228.13  228.24 NON_SPEECH
# segment_302  228.24  228.66 SPEECH
# segment_303  228.66  228.83 NON_SPEECH
# segment_304  228.83  228.99 SPEECH
# segment_305  228.99  237.86 NON_SPEECH
# segment_306  237.86  238.44 SPEECH
# segment_307  238.44  238.63 NON_SPEECH
# segment_308  238.63  239.29 SPEECH
# segment_309  239.29  239.37 NON_SPEECH
# segment_310  239.37  239.73 SPEECH
# segment_311  239.73  240.03 NON_SPEECH
# segment_312  240.03  241.48 SPEECH
# segment_313  241.48  241.91 NON_SPEECH
# segment_314  241.91  242.76 SPEECH
# segment_315  242.76  243.17 NON_SPEECH
# segment_316  243.17  243.64 SPEECH
# segment_317  243.64  243.70 NON_SPEECH
# segment_318  243.70  244.00 SPEECH
# segment_319  244.00  244.20 NON_SPEECH
# segment_320  244.20  244.41 SPEECH
# segment_321  244.41  246.96 NON_SPEECH
# segment_322  246.96  247.01 SPEECH
# segment_323  247.01  247.06 NON_SPEECH
# segment_324  247.06  247.26 SPEECH
# segment_325  247.26  247.37 NON_SPEECH
# segment_326  247.37  248.68 SPEECH
# segment_327  248.68  248.76 NON_SPEECH
# segment_328  248.76  249.10 SPEECH
# segment_329  249.10  249.18 NON_SPEECH
# segment_330  249.18  249.87 SPEECH
# segment_331  249.87  250.00 NON_SPEECH
# segment_332  250.00  250.76 SPEECH
# segment_333  250.76  251.10 NON_SPEECH
# segment_334  251.10  251.28 SPEECH
# segment_335  251.28  251.45 NON_SPEECH
# segment_336  251.45  251.87 SPEECH
# segment_337  251.87  251.90 NON_SPEECH
# segment_338  251.90  253.09 SPEECH
# segment_339  253.09  253.22 NON_SPEECH
# segment_340  253.22  253.61 SPEECH
# segment_341  253.61  253.74 NON_SPEECH
# segment_342  253.74  255.09 SPEECH
# segment_343  255.09  255.68 NON_SPEECH
# segment_344  255.68  256.41 SPEECH
# segment_345  256.41  256.48 NON_SPEECH
# segment_346  256.48  256.97 SPEECH
# segment_347  256.97  289.79 NON_SPEECH
# segment_348  289.79  289.95 SPEECH
# segment_349  289.95  290.10 NON_SPEECH
# segment_350  290.10  290.60 SPEECH
# segment_351  290.60  291.01 NON_SPEECH
# segment_352  291.01  291.91 SPEECH
# segment_353  291.91  292.09 NON_SPEECH
# segment_354  292.09  292.47 SPEECH
# segment_355  292.47  293.18 NON_SPEECH
# segment_356  293.18  294.73 SPEECH
# segment_357  294.73  295.56 NON_SPEECH
# segment_358  295.56  296.62 SPEECH
# segment_359  296.62  296.67 NON_SPEECH
# segment_360  296.67  297.03 SPEECH
# segment_361  297.03  297.11 NON_SPEECH
# segment_362  297.11  297.42 SPEECH
# segment_363  297.42  297.76 NON_SPEECH
# segment_364  297.76  297.89 SPEECH
# segment_365  297.89  297.92 NON_SPEECH
# segment_366  297.92  298.31 SPEECH
# segment_367  298.31  298.35 NON_SPEECH
# segment_368  298.35  298.60 SPEECH
# segment_369  298.60  298.64 NON_SPEECH
# segment_370  298.64  298.89 SPEECH
# segment_371  298.89  299.65 NON_SPEECH

# %% [markdown]
# Users can have a more or less selective VAD by playing with `activation_th` and `deactivation_th`.
#
# Differently from the neural VAD, the energy VAD tends to oversegment the input. We improve that by post-processing the boundaries, as will be shown below.

# %% [markdown]
# ### 5- Merge close segments
# The users might need to select the desired resolution for the VAD (the optimal level of granularity might depend on the task).
#
# For instance, it could make sense to **merge segments** that are too close to each other.
#
# This is done with the following method:

# %%
# 5- Merge segments that are too close
boundaries = VAD.merge_close_segments(boundaries, close_th=0.250)
VAD.save_boundaries(boundaries, audio_file=audio_file)
# Out:
# segment_001  0.00  1.29 NON_SPEECH
# segment_002  1.29  5.02 SPEECH
# segment_003  5.02  14.75 NON_SPEECH
# segment_004  14.75  17.15 SPEECH
# segment_005  17.15  18.33 NON_SPEECH
# segment_006  18.33  20.51 SPEECH
# segment_007  20.51  28.69 NON_SPEECH
# segment_008  28.69  32.77 SPEECH
# segment_009  32.77  33.06 NON_SPEECH
# segment_010  33.06  33.33 SPEECH
# segment_011  33.33  33.63 NON_SPEECH
# segment_012  33.63  36.04 SPEECH
# segment_013  36.04  38.52 NON_SPEECH
# segment_014  38.52  39.24 SPEECH
# segment_015  39.24  39.50 NON_SPEECH
# segment_016  39.50  41.97 SPEECH
# segment_017  41.97  42.48 NON_SPEECH
# segment_018  42.48  42.84 SPEECH
# segment_019  42.84  43.10 NON_SPEECH
# segment_020  43.10  46.46 SPEECH
# segment_021  46.46  46.79 NON_SPEECH
# segment_022  46.79  49.09 SPEECH
# segment_023  49.09  49.67 NON_SPEECH
# segment_024  49.67  51.15 SPEECH
# segment_025  51.15  62.83 NON_SPEECH
# segment_026  62.83  64.18 SPEECH
# segment_027  64.18  65.69 NON_SPEECH
# segment_028  65.69  66.17 SPEECH
# segment_029  66.17  66.70 NON_SPEECH
# segment_030  66.70  66.84 SPEECH
# segment_031  66.84  67.20 NON_SPEECH
# segment_032  67.20  69.99 SPEECH
# segment_033  69.99  70.28 NON_SPEECH
# segment_034  70.28  74.24 SPEECH
# segment_035  74.24  81.41 NON_SPEECH
# segment_036  81.41  82.49 SPEECH
# segment_037  82.49  82.97 NON_SPEECH
# segment_038  82.97  84.11 SPEECH
# segment_039  84.11  85.03 NON_SPEECH
# segment_040  85.03  85.49 SPEECH
# segment_041  85.49  86.09 NON_SPEECH
# segment_042  86.09  86.25 SPEECH
# segment_043  86.25  86.68 NON_SPEECH
# segment_044  86.68  92.14 SPEECH
# segment_045  92.14  92.78 NON_SPEECH
# segment_046  92.78  94.38 SPEECH
# segment_047  94.38  97.54 NON_SPEECH
# segment_048  97.54  98.10 SPEECH
# segment_049  98.10  98.49 NON_SPEECH
# segment_050  98.49  102.67 SPEECH
# segment_051  102.67  122.50 NON_SPEECH
# segment_052  122.50  123.79 SPEECH
# segment_053  123.79  124.18 NON_SPEECH
# segment_054  124.18  128.11 SPEECH
# segment_055  128.11  148.34 NON_SPEECH
# segment_056  148.34  156.23 SPEECH
# segment_057  156.23  156.51 NON_SPEECH
# segment_058  156.51  158.23 SPEECH
# segment_059  158.23  158.72 NON_SPEECH
# segment_060  158.72  164.30 SPEECH
# segment_061  164.30  167.48 NON_SPEECH
# segment_062  167.48  172.31 SPEECH
# segment_063  172.31  206.12 NON_SPEECH
# segment_064  206.12  209.38 SPEECH
# segment_065  209.38  209.69 NON_SPEECH
# segment_066  209.69  212.67 SPEECH
# segment_067  212.67  213.03 NON_SPEECH
# segment_068  213.03  214.79 SPEECH
# segment_069  214.79  215.86 NON_SPEECH
# segment_070  215.86  216.80 SPEECH
# segment_071  216.80  217.22 NON_SPEECH
# segment_072  217.22  222.33 SPEECH
# segment_073  222.33  222.70 NON_SPEECH
# segment_074  222.70  224.78 SPEECH
# segment_075  224.78  225.23 NON_SPEECH
# segment_076  225.23  225.84 SPEECH
# segment_077  225.84  227.51 NON_SPEECH
# segment_078  227.51  228.99 SPEECH
# segment_079  228.99  237.86 NON_SPEECH
# segment_080  237.86  239.73 SPEECH
# segment_081  239.73  240.03 NON_SPEECH
# segment_082  240.03  241.48 SPEECH
# segment_083  241.48  241.91 NON_SPEECH
# segment_084  241.91  242.76 SPEECH
# segment_085  242.76  243.17 NON_SPEECH
# segment_086  243.17  244.41 SPEECH
# segment_087  244.41  246.96 NON_SPEECH
# segment_088  246.96  250.76 SPEECH
# segment_089  250.76  251.10 NON_SPEECH
# segment_090  251.10  255.09 SPEECH
# segment_091  255.09  255.68 NON_SPEECH
# segment_092  255.68  256.97 SPEECH
# segment_093  256.97  289.79 NON_SPEECH
# segment_094  289.79  290.60 SPEECH
# segment_095  290.60  291.01 NON_SPEECH
# segment_096  291.01  292.47 SPEECH
# segment_097  292.47  293.18 NON_SPEECH
# segment_098  293.18  294.73 SPEECH
# segment_099  294.73  295.56 NON_SPEECH
# segment_100  295.56  297.42 SPEECH
# segment_101  297.42  297.76 NON_SPEECH
# segment_102  297.76  298.89 SPEECH
# segment_103  298.89  299.65 NON_SPEECH

# %% [markdown]
# In this case, we merged segments that are closer than 250 ms. Users can play with `close_th` and tune it according to their needs.

# %% [markdown]
# ### 6- Remove short segments
# It could also make sense to remove short isolated segments that might be misclassified as speech:

# %%
# 6- Remove segments that are too short
boundaries = VAD.remove_short_segments(boundaries, len_th=0.250)
VAD.save_boundaries(boundaries, audio_file=audio_file)
# Out:
# segment_001  0.00  1.29 NON_SPEECH
# segment_002  1.29  5.02 SPEECH
# segment_003  5.02  14.75 NON_SPEECH
# segment_004  14.75  17.15 SPEECH
# segment_005  17.15  18.33 NON_SPEECH
# segment_006  18.33  20.51 SPEECH
# segment_007  20.51  28.69 NON_SPEECH
# segment_008  28.69  32.77 SPEECH
# segment_009  32.77  33.06 NON_SPEECH
# segment_010  33.06  33.33 SPEECH
# segment_011  33.33  33.63 NON_SPEECH
# segment_012  33.63  36.04 SPEECH
# segment_013  36.04  38.52 NON_SPEECH
# segment_014  38.52  39.24 SPEECH
# segment_015  39.24  39.50 NON_SPEECH
# segment_016  39.50  41.97 SPEECH
# segment_017  41.97  42.48 NON_SPEECH
# segment_018  42.48  42.84 SPEECH
# segment_019  42.84  43.10 NON_SPEECH
# segment_020  43.10  46.46 SPEECH
# segment_021  46.46  46.79 NON_SPEECH
# segment_022  46.79  49.09 SPEECH
# segment_023  49.09  49.67 NON_SPEECH
# segment_024  49.67  51.15 SPEECH
# segment_025  51.15  62.83 NON_SPEECH
# segment_026  62.83  64.18 SPEECH
# segment_027  64.18  65.69 NON_SPEECH
# segment_028  65.69  66.17 SPEECH
# segment_029  66.17  67.20 NON_SPEECH
# segment_030  67.20  69.99 SPEECH
# segment_031  69.99  70.28 NON_SPEECH
# segment_032  70.28  74.24 SPEECH
# segment_033  74.24  81.41 NON_SPEECH
# segment_034  81.41  82.49 SPEECH
# segment_035  82.49  82.97 NON_SPEECH
# segment_036  82.97  84.11 SPEECH
# segment_037  84.11  85.03 NON_SPEECH
# segment_038  85.03  85.49 SPEECH
# segment_039  85.49  86.68 NON_SPEECH
# segment_040  86.68  92.14 SPEECH
# segment_041  92.14  92.78 NON_SPEECH
# segment_042  92.78  94.38 SPEECH
# segment_043  94.38  97.54 NON_SPEECH
# segment_044  97.54  98.10 SPEECH
# segment_045  98.10  98.49 NON_SPEECH
# segment_046  98.49  102.67 SPEECH
# segment_047  102.67  122.50 NON_SPEECH
# segment_048  122.50  123.79 SPEECH
# segment_049  123.79  124.18 NON_SPEECH
# segment_050  124.18  128.11 SPEECH
# segment_051  128.11  148.34 NON_SPEECH
# segment_052  148.34  156.23 SPEECH
# segment_053  156.23  156.51 NON_SPEECH
# segment_054  156.51  158.23 SPEECH
# segment_055  158.23  158.72 NON_SPEECH
# segment_056  158.72  164.30 SPEECH
# segment_057  164.30  167.48 NON_SPEECH
# segment_058  167.48  172.31 SPEECH
# segment_059  172.31  206.12 NON_SPEECH
# segment_060  206.12  209.38 SPEECH
# segment_061  209.38  209.69 NON_SPEECH
# segment_062  209.69  212.67 SPEECH
# segment_063  212.67  213.03 NON_SPEECH
# segment_064  213.03  214.79 SPEECH
# segment_065  214.79  215.86 NON_SPEECH
# segment_066  215.86  216.80 SPEECH
# segment_067  216.80  217.22 NON_SPEECH
# segment_068  217.22  222.33 SPEECH
# segment_069  222.33  222.70 NON_SPEECH
# segment_070  222.70  224.78 SPEECH
# segment_071  224.78  225.23 NON_SPEECH
# segment_072  225.23  225.84 SPEECH
# segment_073  225.84  227.51 NON_SPEECH
# segment_074  227.51  228.99 SPEECH
# segment_075  228.99  237.86 NON_SPEECH
# segment_076  237.86  239.73 SPEECH
# segment_077  239.73  240.03 NON_SPEECH
# segment_078  240.03  241.48 SPEECH
# segment_079  241.48  241.91 NON_SPEECH
# segment_080  241.91  242.76 SPEECH
# segment_081  242.76  243.17 NON_SPEECH
# segment_082  243.17  244.41 SPEECH
# segment_083  244.41  246.96 NON_SPEECH
# segment_084  246.96  250.76 SPEECH
# segment_085  250.76  251.10 NON_SPEECH
# segment_086  251.10  255.09 SPEECH
# segment_087  255.09  255.68 NON_SPEECH
# segment_088  255.68  256.97 SPEECH
# segment_089  256.97  289.79 NON_SPEECH
# segment_090  289.79  290.60 SPEECH
# segment_091  290.60  291.01 NON_SPEECH
# segment_092  291.01  292.47 SPEECH
# segment_093  292.47  293.18 NON_SPEECH
# segment_094  293.18  294.73 SPEECH
# segment_095  294.73  295.56 NON_SPEECH
# segment_096  295.56  297.42 SPEECH
# segment_097  297.42  297.76 NON_SPEECH
# segment_098  297.76  298.89 SPEECH
# segment_099  298.89  299.65 NON_SPEECH

# %% [markdown]
# In this case, we remove segments that are shorter than 250 ms. Note that we first merged segments that are close and only after we removed the short ones. This helps to remove short "isolated"  segments only.

# %% [markdown]
# ## 7- Double check speech segments (optional)
#
# At this point, we can take the post-processed speech segments and double-check if they really contain speech. This is done in this way:

# %%
# 7- Double-check speech segments (optional).
boundaries = VAD.double_check_speech_segments(boundaries, audio_file,  speech_th=0.5)
VAD.save_boundaries(boundaries, audio_file=audio_file)
# Out:
# segment_001  0.00  1.29 NON_SPEECH
# segment_002  1.29  5.02 SPEECH
# segment_003  5.02  14.75 NON_SPEECH
# segment_004  14.75  17.15 SPEECH
# segment_005  17.15  18.33 NON_SPEECH
# segment_006  18.33  20.51 SPEECH
# segment_007  20.51  28.69 NON_SPEECH
# segment_008  28.69  32.77 SPEECH
# segment_009  32.77  33.06 NON_SPEECH
# segment_010  33.06  33.33 SPEECH
# segment_011  33.33  33.63 NON_SPEECH
# segment_012  33.63  36.04 SPEECH
# segment_013  36.04  38.52 NON_SPEECH
# segment_014  38.52  39.24 SPEECH
# segment_015  39.24  39.50 NON_SPEECH
# segment_016  39.50  41.97 SPEECH
# segment_017  41.97  42.48 NON_SPEECH
# segment_018  42.48  42.84 SPEECH
# segment_019  42.84  43.10 NON_SPEECH
# segment_020  43.10  46.46 SPEECH
# segment_021  46.46  46.79 NON_SPEECH
# segment_022  46.79  49.09 SPEECH
# segment_023  49.09  49.67 NON_SPEECH
# segment_024  49.67  51.15 SPEECH
# segment_025  51.15  62.83 NON_SPEECH
# segment_026  62.83  64.18 SPEECH
# segment_027  64.18  65.69 NON_SPEECH
# segment_028  65.69  66.17 SPEECH
# segment_029  66.17  67.20 NON_SPEECH
# segment_030  67.20  69.99 SPEECH
# segment_031  69.99  70.28 NON_SPEECH
# segment_032  70.28  74.24 SPEECH
# segment_033  74.24  81.41 NON_SPEECH
# segment_034  81.41  82.49 SPEECH
# segment_035  82.49  82.97 NON_SPEECH
# segment_036  82.97  84.11 SPEECH
# segment_037  84.11  85.03 NON_SPEECH
# segment_038  85.03  85.49 SPEECH
# segment_039  85.49  86.68 NON_SPEECH
# segment_040  86.68  92.14 SPEECH
# segment_041  92.14  92.78 NON_SPEECH
# segment_042  92.78  94.38 SPEECH
# segment_043  94.38  97.54 NON_SPEECH
# segment_044  97.54  98.10 SPEECH
# segment_045  98.10  98.49 NON_SPEECH
# segment_046  98.49  102.67 SPEECH
# segment_047  102.67  122.50 NON_SPEECH
# segment_048  122.50  123.79 SPEECH
# segment_049  123.79  124.18 NON_SPEECH
# segment_050  124.18  128.11 SPEECH
# segment_051  128.11  148.34 NON_SPEECH
# segment_052  148.34  156.23 SPEECH
# segment_053  156.23  156.51 NON_SPEECH
# segment_054  156.51  158.23 SPEECH
# segment_055  158.23  158.72 NON_SPEECH
# segment_056  158.72  164.30 SPEECH
# segment_057  164.30  167.48 NON_SPEECH
# segment_058  167.48  172.31 SPEECH
# segment_059  172.31  206.12 NON_SPEECH
# segment_060  206.12  209.38 SPEECH
# segment_061  209.38  209.69 NON_SPEECH
# segment_062  209.69  212.67 SPEECH
# segment_063  212.67  213.03 NON_SPEECH
# segment_064  213.03  214.79 SPEECH
# segment_065  214.79  215.86 NON_SPEECH
# segment_066  215.86  216.80 SPEECH
# segment_067  216.80  217.22 NON_SPEECH
# segment_068  217.22  222.33 SPEECH
# segment_069  222.33  222.70 NON_SPEECH
# segment_070  222.70  224.78 SPEECH
# segment_071  224.78  225.23 NON_SPEECH
# segment_072  225.23  225.84 SPEECH
# segment_073  225.84  227.51 NON_SPEECH
# segment_074  227.51  228.99 SPEECH
# segment_075  228.99  237.86 NON_SPEECH
# segment_076  237.86  239.73 SPEECH
# segment_077  239.73  240.03 NON_SPEECH
# segment_078  240.03  241.48 SPEECH
# segment_079  241.48  241.91 NON_SPEECH
# segment_080  241.91  242.76 SPEECH
# segment_081  242.76  243.17 NON_SPEECH
# segment_082  243.17  244.41 SPEECH
# segment_083  244.41  246.96 NON_SPEECH
# segment_084  246.96  250.76 SPEECH
# segment_085  250.76  251.10 NON_SPEECH
# segment_086  251.10  255.09 SPEECH
# segment_087  255.09  255.68 NON_SPEECH
# segment_088  255.68  256.97 SPEECH
# segment_089  256.97  289.79 NON_SPEECH
# segment_090  289.79  290.60 SPEECH
# segment_091  290.60  291.01 NON_SPEECH
# segment_092  291.01  292.47 SPEECH
# segment_093  292.47  293.18 NON_SPEECH
# segment_094  293.18  294.73 SPEECH
# segment_095  294.73  295.56 NON_SPEECH
# segment_096  295.56  297.42 SPEECH
# segment_097  297.42  297.76 NON_SPEECH
# segment_098  297.76  298.89 SPEECH
# segment_099  298.89  299.65 NON_SPEECH

# %% [markdown]
# The method uses one more time the neural VAD on the detected speech segments. If the **average posterior probability within the segment** is larger than `speech_th` (in this case, `speech_th=0.5`), the speech segment is confirmed. Otherwise,  it is removed.

# %% [markdown]
# ## Visualization
#
# We also implemented some utilities to help users visualizing the output of the VAD:

# %%
upsampled_boundaries = VAD.upsample_boundaries(boundaries, audio_file)

# %% [markdown]
# This function creates a "VAD signal" with the **same dimensionality** as the original audio recording. This way, one can plot them jointly:

# %%
time = torch.linspace(0, signal.shape[0]/fs, steps=signal.shape[0])
plt.plot(time, signal)
plt.plot(time, upsampled_boundaries.squeeze())

# %% [markdown]
# For more details, one can also upsample and visualize VAD scores:

# %%
upsampled_vad_scores = VAD.upsample_VAD(prob_chunks, audio_file)

plt.plot(time, signal)
plt.plot(time, upsampled_boundaries.squeeze())
plt.plot(time, upsampled_vad_scores.squeeze())

# %% [markdown]
# As an alternative, users can save the VAD file and open it with the original one using an audio visualization software like audacity.
#
#
# **That's all! Happy VAD!**

# %% [markdown]
# ---
#
# # Appendix: on using energy-based VAD
#
# If energy-based VAD is used, the order of the merge, remove, double-check operations matters. Let's use `double_check_speech_segments` right away after energy-based VAD and then `merge_close_segments`. Some speech frames are dropped:

# %%
# plotted boundaries may be scaled down to compare many at once
def plot_boundaries(b, color):
  upsampled = VAD.upsample_boundaries(b, audio_file)
  plt.plot(time, upsampled.squeeze(), color)


# first figures - from CRDNN VAD to energy VAD
fig, axs = plt.subplots(3, 3, figsize=(16, 12))
plt.sca(axs[0, 0])
plt.title('1a. CRDNN VAD scores')
plt.plot(time, signal)

plt.plot(time, upsampled_vad_scores.squeeze(), 'green')

# CRDNN boundaries
plt.sca(axs[1, 0])
plt.title('1b. CRDNN VAD boundaries')
plt.plot(time, signal)

boundaries = VAD.get_boundaries(prob_th)
plot_boundaries(boundaries, 'orange')

# energy VAD boundaries
plt.sca(axs[2, 0])
plt.title('1c. Energy VAD boundaries based on CRDNN')
plt.plot(time, signal)

boundaries_energy = VAD.energy_VAD(audio_file, boundaries, activation_th=0.8, deactivation_th=0.0)
plot_boundaries(boundaries_energy, 'purple')

# second figure - double-check, then merge
plt.sca(axs[0, 1])
plt.title('2a. Energy VAD (same as 1c)')
plt.plot(time, signal)

plot_boundaries(boundaries_energy, 'purple')

# double-check
plt.sca(axs[1, 1])
plt.title('2b. Double-check (too early)')
plt.plot(time, signal)

boundaries = VAD.double_check_speech_segments(boundaries_energy, audio_file,  speech_th=0.5)
plot_boundaries(boundaries, 'red')

# merge (too late)
plt.sca(axs[2, 1])
plt.title('2c. Merge short segments (too late)')
plt.plot(time, signal)

boundaries = VAD.merge_close_segments(boundaries, close_th=0.250)
plot_boundaries(boundaries, 'black')

# third figure - merge, remove, double-check
plt.sca(axs[0, 2])
plt.title('3a. Energy VAD (same as 1c)')
plt.plot(time, signal)

plot_boundaries(boundaries_energy, 'purple')

# merge
plt.sca(axs[1, 2])
plt.title('3b. Merge short segments (as above)')
plt.plot(time, signal)

boundaries = VAD.merge_close_segments(boundaries_energy, close_th=0.250)
plot_boundaries(boundaries, 'black')

# merge
plt.sca(axs[2, 2])
plt.title('3c. Remove short segments & double-check (as above)')
plt.plot(time, signal)

boundaries = VAD.remove_short_segments(boundaries, len_th=0.250)
boundaries = VAD.double_check_speech_segments(boundaries, audio_file,  speech_th=0.5)
plot_boundaries(boundaries, 'red')
